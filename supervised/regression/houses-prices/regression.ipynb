# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
data_raw = pd.read_csv('train.csv', index_col=['Id'])
data_raw.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.options.display.max_rows = 999
data_raw.describe(include='all').transpose()
# Out:
#                 count unique      top  freq          mean           std  \
# MSSubClass     1460.0    NaN      NaN   NaN      56.89726     42.300571
# MSZoning         1460      5       RL  1151           NaN           NaN
# LotFrontage    1201.0    NaN      NaN   NaN     70.049958     24.284752
# LotArea        1460.0    NaN      NaN   NaN  10516.828082   9981.264932
# Street           1460      2     Pave  1454           NaN           NaN
# Alley              91      2     Grvl    50           NaN           NaN
# LotShape         1460      4      Reg   925           NaN           NaN
# LandContour      1460      4      Lvl  1311           NaN           NaN
# Utilities        1460      2   AllPub  1459           NaN           NaN
# LotConfig        1460      5   Inside  1052           NaN           NaN
# LandSlope        1460      3      Gtl  1382           NaN           NaN
# Neighborhood     1460     25    NAmes   225           NaN           NaN
# ...

# %%
data_raw.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
data = data_raw.drop(['LotFrontage','Alley','FireplaceQu','PoolQC','Fence','MiscFeature'],axis=1)

# %%
data.describe(include = 'all').transpose()
# Out:
#                 count unique      top  freq          mean           std  \
# MSSubClass     1460.0    NaN      NaN   NaN      56.89726     42.300571
# MSZoning         1460      5       RL  1151           NaN           NaN
# LotArea        1460.0    NaN      NaN   NaN  10516.828082   9981.264932
# Street           1460      2     Pave  1454           NaN           NaN
# LotShape         1460      4      Reg   925           NaN           NaN
# LandContour      1460      4      Lvl  1311           NaN           NaN
# Utilities        1460      2   AllPub  1459           NaN           NaN
# LotConfig        1460      5   Inside  1052           NaN           NaN
# LandSlope        1460      3      Gtl  1382           NaN           NaN
# Neighborhood     1460     25    NAmes   225           NaN           NaN
# Condition1       1460      9     Norm  1260           NaN           NaN
# Condition2       1460      8     Norm  1445           NaN           NaN
# ...

# %%
data_no_mv = data.dropna()

# %%
data_no_mv.describe(include='all').transpose()
# Out:
#                 count unique      top  freq           mean           std  \
# MSSubClass     1338.0    NaN      NaN   NaN      56.136024     41.252576
# MSZoning         1338      5       RL  1066            NaN           NaN
# LotArea        1338.0    NaN      NaN   NaN   10706.294469  10336.621126
# Street           1338      2     Pave  1333            NaN           NaN
# LotShape         1338      4      Reg   829            NaN           NaN
# LandContour      1338      4      Lvl  1206            NaN           NaN
# Utilities        1338      2   AllPub  1337            NaN           NaN
# LotConfig        1338      5   Inside   957            NaN           NaN
# LandSlope        1338      3      Gtl  1265            NaN           NaN
# Neighborhood     1338     25    NAmes   209            NaN           NaN
# Condition1       1338      9     Norm  1162            NaN           NaN
# Condition2       1338      8     Norm  1324            NaN           NaN
# ...

# %%
sns.distplot(data_no_mv['SalePrice'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
q = data_no_mv['SalePrice'].quantile(0.99)
data_1 = data_no_mv[data_no_mv['SalePrice']<q]
data_1.describe()
# Out:
#         MSSubClass        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1324.000000    1324.000000  1324.000000  1324.000000  1324.000000
# mean     56.204683   10609.203927     6.185801     5.598943  1972.787009
# std      41.418112   10284.848496     1.287856     1.078211    29.471458
# min      20.000000    1300.000000     2.000000     2.000000  1880.000000
# 25%      20.000000    7700.000000     5.000000     5.000000  1955.000000
# 50%      50.000000    9579.500000     6.000000     5.000000  1975.500000
# 75%      70.000000   11649.750000     7.000000     6.000000  2001.000000
# max     190.000000  215245.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1324.000000  1324.000000  1324.000000  1324.000000  1324.000000  ...
# mean    1985.478097   105.678248   456.754532    49.331571   579.829305  ...
# std       20.308810   176.151538   448.673196   166.458576   436.853158  ...
# ...

# %%
sns.distplot(data_1['SalePrice'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
data_no_mv.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotArea            int64
# Street            object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# Heating           object
# ...

# %%
sns.distplot(data_no_mv['MSSubClass'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSSubClass', ylabel='Density'>

# %%
sns.distplot(data_no_mv['LotArea'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %%
q = data_1['LotArea'].quantile(0.99)
data_2 = data_1[data_1['LotArea']<q]
data_2.describe()
# Out:
#         MSSubClass       LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1310.000000   1310.000000  1310.000000  1310.000000  1310.000000
# mean     56.293893   9826.482443     6.177863     5.596947  1972.816794
# std      41.388541   4151.719514     1.279669     1.078715    29.510263
# min      20.000000   1300.000000     2.000000     2.000000  1880.000000
# 25%      20.000000   7678.000000     5.000000     5.000000  1955.250000
# 50%      50.000000   9548.500000     6.000000     5.000000  1976.000000
# 75%      70.000000  11576.250000     7.000000     6.000000  2001.000000
# max     190.000000  36500.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1310.000000  1310.000000  1310.000000  1310.000000  1310.000000  ...
# mean    1985.430534   104.587023   447.276336    47.916794   581.749618  ...
# std       20.324660   174.084412   419.633672   163.294627   437.449977  ...
# ...

# %%
sns.distplot(data_2['LotArea'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %%
sns.distplot(data_2['OverallQual'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='OverallQual', ylabel='Density'>

# %%
sns.distplot(data_2['YearBuilt'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearBuilt', ylabel='Density'>

# %%
q = data_2['YearBuilt'].quantile(0.01)
data_3 = data_2[data_2['YearBuilt']>q]
data_3.describe()
# Out:
#         MSSubClass       LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1290.000000   1290.000000  1290.000000  1290.000000  1290.000000
# mean     55.697674   9815.281395     6.189147     5.587597  1974.073643
# std      40.833748   4163.498049     1.270861     1.054968    27.924674
# min      20.000000   1300.000000     2.000000     2.000000  1904.000000
# 25%      20.000000   7646.000000     5.000000     5.000000  1957.000000
# 50%      50.000000   9536.000000     6.000000     5.000000  1976.000000
# 75%      70.000000  11576.250000     7.000000     6.000000  2001.000000
# max     190.000000  36500.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1290.000000  1290.000000  1290.000000  1290.000000  1290.000000  ...
# mean    1985.602326   106.208527   452.157364    48.356589   579.262791  ...
# std       20.263987   174.937836   419.575142   164.175260   438.087869  ...
# ...

# %%
sns.distplot(data_3['YearBuilt'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearBuilt', ylabel='Density'>

# %%
sns.distplot(data_3['MasVnrArea'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MasVnrArea', ylabel='Density'>

# %%
sns.distplot(data_3['TotalBsmtSF'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='Density'>

# %%
q = data_3['TotalBsmtSF'].quantile(0.99)
data_4 = data_3[data_3['TotalBsmtSF']<q]
data_4.describe()
# Out:
#         MSSubClass       LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1277.000000   1277.000000  1277.000000  1277.000000  1277.000000
# mean     56.029757   9777.314017     6.170713     5.591229  1973.929522
# std      40.893440   4157.817248     1.257200     1.055892    27.974401
# min      20.000000   1300.000000     2.000000     2.000000  1904.000000
# 25%      20.000000   7590.000000     5.000000     5.000000  1957.000000
# 50%      50.000000   9500.000000     6.000000     5.000000  1976.000000
# 75%      70.000000  11478.000000     7.000000     6.000000  2001.000000
# max     190.000000  36500.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1277.000000  1277.000000  1277.000000  1277.000000  1277.000000  ...
# mean    1985.571652   103.469851   447.378230    48.065779   572.225529  ...
# std       20.286017   168.853937   413.541159   163.476702   428.856525  ...
# ...

# %%
sns.distplot(data_4['TotalBsmtSF'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='Density'>

# %%
sns.distplot(data_4['GarageArea'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GarageArea', ylabel='Density'>

# %%
q = data_4['GarageArea'].quantile(0.99)
data_5 = data_4[data_4['GarageArea']<q]
data_5.describe()
# Out:
#         MSSubClass       LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1264.000000   1264.000000  1264.000000  1264.000000  1264.000000
# mean     55.909810   9719.512658     6.163766     5.596519  1973.825158
# std      40.846193   4053.197254     1.247991     1.052924    27.967354
# min      20.000000   1300.000000     2.000000     2.000000  1904.000000
# 25%      20.000000   7583.000000     5.000000     5.000000  1956.000000
# 50%      50.000000   9478.500000     6.000000     5.000000  1976.000000
# 75%      70.000000  11446.500000     7.000000     6.000000  2001.000000
# max     190.000000  36500.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1264.000000  1264.000000  1264.000000  1264.000000  1264.000000  ...
# mean    1985.511867   101.235759   445.924051    48.560127   570.905854  ...
# std       20.287284   165.839198   411.442867   164.242756   427.569979  ...
# ...

# %%
sns.distplot(data_5['GarageArea'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GarageArea', ylabel='Density'>

# %%
data_cleaned = data_5.reset_index(drop=True)

# %%
data_cleaned.describe(include='all')
# Out:
#          MSSubClass MSZoning       LotArea Street LotShape LandContour  \
# count   1264.000000     1264   1264.000000   1264     1264        1264
# unique          NaN        5           NaN      2        4           4
# top             NaN       RL           NaN   Pave      Reg         Lvl
# freq            NaN     1014           NaN   1262      789        1151
# mean      55.909810      NaN   9719.512658    NaN      NaN         NaN
# std       40.846193      NaN   4053.197254    NaN      NaN         NaN
# min       20.000000      NaN   1300.000000    NaN      NaN         NaN
# 25%       20.000000      NaN   7583.000000    NaN      NaN         NaN
# 50%       50.000000      NaN   9478.500000    NaN      NaN         NaN
# 75%       70.000000      NaN  11446.500000    NaN      NaN         NaN
# max      190.000000      NaN  36500.000000    NaN      NaN         NaN
#
#        Utilities LotConfig LandSlope Neighborhood  ... EnclosedPorch  \
# ...

# %%
f, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,sharey=True,figsize=(15,4))
ax1.scatter(data_cleaned['LotArea'],data_cleaned['SalePrice'])
ax1.set_title('Price and LotArea')
ax2.scatter(data_cleaned['YearBuilt'],data_cleaned['SalePrice'])
ax2.set_title('Price and YearBuilt')
ax3.scatter(data_cleaned['TotalBsmtSF'],data_cleaned['SalePrice'])
ax3.set_title('Price and TotalBsmtSF')
ax4.scatter(data_cleaned['GarageArea'],data_cleaned['SalePrice'])
ax4.set_title('Price and GarageArea')
plt.show()

# %%
data_cleaned = data_cleaned.drop(['LotArea'],axis=1)

# %%
data_cleaned.columns.values
# Out:
# array(['MSSubClass', 'MSZoning', 'Street', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
cols = ['SalePrice','YearBuilt','TotalBsmtSF','GarageArea']

# %%
data_preprocessed = data_cleaned[cols]

# %%
targets = data_preprocessed['SalePrice']
inputs = data_preprocessed.drop(['SalePrice'],axis=1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size = 0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)

# %%
plt.scatter(y_train,y_hat, alpha = 0.2)

# %%
reg.score(x_train,y_train)
# Out:
# 0.569686339055566

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test,y_hat_test,alpha=0.2)

# %%
sns.distplot(y_train - y_hat)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
sns.distplot(y_test - y_hat_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
data_test = pd.read_csv('test.csv',index_col=['Id'])
data_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
# ...

# %%
data_test.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
cols_test = ['YearBuilt','TotalBsmtSF','GarageArea']
test = data_test[cols_test]

# %%
test.isnull().sum()
# Out:
# YearBuilt      0
# TotalBsmtSF    1
# GarageArea     1
# dtype: int64

# %%
test['TotalBsmtSF'] = test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].median())
test['GarageArea'] = test['GarageArea'].fillna(test['GarageArea'].median())
# Out:
# /var/folders/06/pvd15jn934z7w3kzys42mzlc0000gn/T/ipykernel_4410/3229279345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['TotalBsmtSF'] = test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].median())
# /var/folders/06/pvd15jn934z7w3kzys42mzlc0000gn/T/ipykernel_4410/3229279345.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['GarageArea'] = test['GarageArea'].fillna(test['GarageArea'].median())

# %%
test.head()
# Out:
#       YearBuilt  TotalBsmtSF  GarageArea
# Id
# 1461       1961        882.0       730.0
# 1462       1958       1329.0       312.0
# 1463       1997        928.0       482.0
# 1464       1998        926.0       470.0
# 1465       1992       1280.0       506.0

# %%
predict = reg.predict(test[cols_test])

# %%
predict
# Out:
# array([189948.59642668, 165944.89161134, 185239.14843599, ...,
#        192870.42969024, 121519.86064525, 207919.51725688])

# %%
test['SalePrice'] = predict
# Out:
# /var/folders/06/pvd15jn934z7w3kzys42mzlc0000gn/T/ipykernel_4410/3731577198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['SalePrice'] = predict

# %%
test.head()
# Out:
#       YearBuilt  TotalBsmtSF  GarageArea      SalePrice
# Id
# 1461       1961        882.0       730.0  189948.596427
# 1462       1958       1329.0       312.0  165944.891611
# 1463       1997        928.0       482.0  185239.148436
# 1464       1998        926.0       470.0  184261.267829
# 1465       1992       1280.0       506.0  208248.981383

# %%
test['SalePrice'].to_csv('submission.csv')
